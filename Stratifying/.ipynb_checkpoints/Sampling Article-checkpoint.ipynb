# %% [markdown]
# # How To Use Sampling in Real-World Machine Learning to Significantly Improve Model Performance

# %% [markdown]
# ## How and when to use sampling in a machine learning project to ensure that predictions are accurate and meaningful

# %% [markdown]
# ### Background
# In a recent machine learning project I was involved in the model looked to be performing well against validation data and was considered ready to be moved into the production environment.
#
# The problem came when the overall ration of predictions on the production dataset looked outlandish and the domain experts fed back that this must be wrong.
#
# This article sets out to explore the issue and how sampling was used to deliver a model that could be used in the production environment with confidence.

# %% [markdown]
# ### Getting Started
# Lets start by importing and initialising the libraries that are needed in the project ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from typing import Tuple

from sklearn.model_selection import train_test_split
from shap import Explainer, plots, initjs
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score

initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ### Importing and Preparing the Data
# The next block of code reads in the data. The data represents a set of customer loans that can be classified into "Repaid" where the customer repays the full amount or "Defaulted" where the customer fails to repay the loan. Where the loan status is null the loan is still in progress and is yet to complete.
#
# Please note that the dataset is entirely fictitious and has been built by the author using the ``Faker`` library to illustrate the problem that was encountered in a real-world machine learning project.
#
# This means that there are no license restrictions on the data and it can be used freely in other projects for testing and learning purposes.
#
# If you would like to know more about ``Faker`` here is a link to the library - https://faker.readthedocs.io/en/master/.

# %%
df_loans = pd.read_excel("Data/CustomerLoansNewV5.xlsx", index_col="CustomerNumber") # Read in the data ...

# One hot encode the categorical columns and remove any special characters from the column names to resolve "LightGBMError: Do not support special JSON characters in feature name." error ...
#df_loans = pd.concat([pd.get_dummies(df_loans, columns=["CustomerGender", "CustomerAccessedAdvice", "CustomerJobTitle", "CustomerDepartment", "EmployerName", "EmployerBusinessActivity", "LoanApplicationMethod", "LoanType"]), df_loans["LoanType"]], axis=1)
df_loans = pd.concat([pd.get_dummies(df_loans, columns=["CustomerGender", "CustomerAccessedAdvice", "CustomerJobTitle", "CustomerDepartment", "EmployerBusinessActivity", "LoanApplicationMethod", "LoanType"]), df_loans["LoanType"]], axis=1)
df_loans.rename(columns = lambda x:re.sub('[^A-Za-z0-9-]+', '', x), inplace=True)

# %%
df_loans.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4054 entries, 29061 to 15168
# Data columns (total 191 columns):
#  #    Column                                                   Dtype
# ---   ------                                                   -----
#  0    CustomerAgeAtStart                                       int64
#  1    LoanExpectedEndDate                                      datetime64[ns]
#  2    LoanStatus                                               object
#  3    CustomerGenderF                                          uint8
#  4    CustomerGenderM                                          uint8
#  5    CustomerAccessedAdviceN                                  uint8
#  6    CustomerAccessedAdviceY                                  uint8
#  7    CustomerJobTitleAccountantCharteredPublicFinance         uint8
#  8    CustomerJobTitleAccountantChartered                      uint8
#  9    CustomerJobTitleActor                                    uint8
#  10   CustomerJobTitleActuary                                  uint8
#  11   CustomerJobTitleAdministratorCivilService                uint8
#  12   CustomerJobTitleAdministratorSports                      uint8
#  13   CustomerJobTitleAirTrafficController                     uint8
#  14   CustomerJobTitleAmbulancePerson                          uint8
#  15   CustomerJobTitleAnalyticalChemist                        uint8
#  16   CustomerJobTitleBiochemistClinical                       uint8
#  17   CustomerJobTitleBiomedicalEngineer                       uint8
#  18   CustomerJobTitleBookseller                               uint8
#  19   CustomerJobTitleBrewingTechnologist                      uint8
#  20   CustomerJobTitleBuildingControlSurveyor                  uint8
#  21   CustomerJobTitleCeramicsDesigner                         uint8
#  22   CustomerJobTitleChiefMarketingOfficer                    uint8
#  23   CustomerJobTitleChiefTechnologyOfficer                   uint8
#  24   CustomerJobTitleClinicalEmbryologist                     uint8
#  25   CustomerJobTitleClinicalResearchAssociate                uint8
#  26   CustomerJobTitleClinicalScientistImmunogenetics          uint8
#  27   CustomerJobTitleCommercialResidentialSurveyor            uint8
#  28   CustomerJobTitleCommunityArtsWorker                      uint8
#  29   CustomerJobTitleCommunityEducationOfficer                uint8
#  30   CustomerJobTitleConservationOfficerhistoricBuildings     uint8
#  31   CustomerJobTitleControlandInstrumentationEngineer        uint8
#  32   CustomerJobTitleCorporateInvestmentBanker                uint8
#  33   CustomerJobTitleCustomerServiceManager                   uint8
#  34   CustomerJobTitleDancer                                   uint8
#  35   CustomerJobTitleDesignerBlownGlassStainedGlass           uint8
#  36   CustomerJobTitleDesignerExhibitionDisplay                uint8
#  37   CustomerJobTitleDesignerFashionClothing                  uint8
#  38   CustomerJobTitleDesignergraphic                          uint8
#  39   CustomerJobTitleDiagnosticRadiographer                   uint8
#  40   CustomerJobTitleDiplomaticServicesOperationalOfficer     uint8
#  41   CustomerJobTitleDispensingOptician                       uint8
#  42   CustomerJobTitleEcologist                                uint8
#  43   CustomerJobTitleEditormagazineFeatures                   uint8
#  44   CustomerJobTitleEducationAdministrator                   uint8
#  45   CustomerJobTitleEducationOfficerEnvironmental            uint8
#  46   CustomerJobTitleEmbryologistClinical                     uint8
#  47   CustomerJobTitleEngineerAeronautical                     uint8
#  48   CustomerJobTitleEngineerAgricultural                     uint8
#  49   CustomerJobTitleEngineerBroadcastingOperations           uint8
#  50   CustomerJobTitleEngineerDrilling                         uint8
#  51   CustomerJobTitleEngineerMaintenance                      uint8
#  52   CustomerJobTitleEngineerManufacturingSystems             uint8
#  53   CustomerJobTitleEngineerPetroleum                        uint8
#  54   CustomerJobTitleEngineerProduction                       uint8
#  55   CustomerJobTitleEngineerSite                             uint8
#  56   CustomerJobTitleEstateAgent                              uint8
#  57   CustomerJobTitleEstateManagerLandAgent                   uint8
#  58   CustomerJobTitleExhibitionDesigner                       uint8
#  59   CustomerJobTitleFacilitiesManager                        uint8
#  60   CustomerJobTitleFashionDesigner                          uint8
#  61   CustomerJobTitleFieldTrialsOfficer                       uint8
#  62   CustomerJobTitleFinancialAdviser                         uint8
#  63   CustomerJobTitleFinancialManager                         uint8
#  64   CustomerJobTitleFinancialPlanner                         uint8
#  65   CustomerJobTitleFineArtist                               uint8
#  66   CustomerJobTitleHealthPromotionSpecialist                uint8
#  67   CustomerJobTitleHigherEducationLecturer                  uint8
#  68   CustomerJobTitleHomeopath                                uint8
#  69   CustomerJobTitleHorticulturalConsultant                  uint8
#  70   CustomerJobTitleHorticulturalTherapist                   uint8
#  71   CustomerJobTitleHospitalPharmacist                       uint8
#  72   CustomerJobTitleHousingManagerOfficer                    uint8
#  73   CustomerJobTitleHydrographicSurveyor                     uint8
#  74   CustomerJobTitleInsuranceBroker                          uint8
#  75   CustomerJobTitleInsuranceClaimsHandler                   uint8
#  76   CustomerJobTitleInsuranceRiskSurveyor                    uint8
#  77   CustomerJobTitleInternationalAidDevelopmentWorker        uint8
#  78   CustomerJobTitleJournalistbroadcasting                   uint8
#  79   CustomerJobTitleLearningMentor                           uint8
#  80   CustomerJobTitleLexicographer                            uint8
#  81   CustomerJobTitleLibrarianpublic                          uint8
#  82   CustomerJobTitleLicensedConveyancer                      uint8
#  83   CustomerJobTitleLossAdjusterChartered                    uint8
#  84   CustomerJobTitleMagazineFeaturesEditor                   uint8
#  85   CustomerJobTitleMaintenanceEngineer                      uint8
#  86   CustomerJobTitleMarineScientist                          uint8
#  87   CustomerJobTitleMarketingExecutive                       uint8
#  88   CustomerJobTitleMediaBuyer                               uint8
#  89   CustomerJobTitleMediaPlanner                             uint8
#  90   CustomerJobTitleMedicalSecretary                         uint8
#  91   CustomerJobTitleMetallurgist                             uint8
#  92   CustomerJobTitleMiningEngineer                           uint8
#  93   CustomerJobTitleMusician                                 uint8
#  94   CustomerJobTitleNavalArchitect                           uint8
#  95   CustomerJobTitleNewspaperJournalist                      uint8
#  96   CustomerJobTitleOccupationalHygienist                    uint8
#  97   CustomerJobTitleOccupationalTherapist                    uint8
#  98   CustomerJobTitleOperationalInvestmentBanker              uint8
#  99   CustomerJobTitleOphthalmologist                          uint8
#  100  CustomerJobTitleOrthoptist                               uint8
#  101  CustomerJobTitlePhysiologicalScientist                   uint8
#  102  CustomerJobTitlePlantBreederGeneticist                   uint8
#  103  CustomerJobTitlePrintmaker                               uint8
#  104  CustomerJobTitleProductionAssistanttelevision            uint8
#  105  CustomerJobTitleProductionManager                        uint8
#  106  CustomerJobTitleProgrammerApplications                   uint8
#  107  CustomerJobTitleProgrammerMultimedia                     uint8
#  108  CustomerJobTitlePsychologistCounselling                  uint8
#  109  CustomerJobTitlePsychologistSportandExercise             uint8
#  110  CustomerJobTitlePsychotherapistChild                     uint8
#  111  CustomerJobTitlePublishingRightsManager                  uint8
#  112  CustomerJobTitleQuarryManager                            uint8
#  113  CustomerJobTitleRadiationProtectionPractitioner          uint8
#  114  CustomerJobTitleRadioBroadcastAssistant                  uint8
#  115  CustomerJobTitleRadiographerdiagnostic                   uint8
#  116  CustomerJobTitleResearchOfficerpoliticalParty            uint8
#  117  CustomerJobTitleResearchScientistLifeSciences            uint8
#  118  CustomerJobTitleResearchScientistPhysicalSciences        uint8
#  119  CustomerJobTitleRestaurantManager                        uint8
#  120  CustomerJobTitleRetailBanker                             uint8
#  121  CustomerJobTitleSalesProfessionalIT                      uint8
#  122  CustomerJobTitleScientistAudiological                    uint8
#  123  CustomerJobTitleScientistClinical                        uint8
#  124  CustomerJobTitleScientistMarine                          uint8
#  125  CustomerJobTitleScientistPhysicalSciences                uint8
#  126  CustomerJobTitleScientistWaterQuality                    uint8
#  127  CustomerJobTitleSecondarySchoolTeacher                   uint8
#  128  CustomerJobTitleSocialResearchOfficerGovernment          uint8
#  129  CustomerJobTitleSolicitor                                uint8
#  130  CustomerJobTitleSpeechandLanguageTherapist               uint8
#  131  CustomerJobTitleStageManager                             uint8
#  132  CustomerJobTitleSurveyorMinerals                         uint8
#  133  CustomerJobTitleSystemsAnalyst                           uint8
#  134  CustomerJobTitleTeacherAdultEducation                    uint8
#  135  CustomerJobTitleTeacherEnglish                           uint8
#  136  CustomerJobTitleTeachingLaboratoryTechnician             uint8
#  137  CustomerJobTitleTelevisionFloorManager                   uint8
#  138  CustomerJobTitleTextileDesigner                          uint8
#  139  CustomerJobTitleTherapistSpeechandLanguage               uint8
#  140  CustomerJobTitleTouristInformationCentreManager          uint8
#  141  CustomerJobTitleTownPlanner                              uint8
#  142  CustomerJobTitleToxicologist                             uint8
#  143  CustomerJobTitleVeterinarySurgeon                        uint8
#  144  CustomerJobTitleVisualMerchandiser                       uint8
#  145  CustomerJobTitleWardenRanger                             uint8
#  146  CustomerJobTitleWarehouseManager                         uint8
#  147  CustomerDepartmentFinance                                uint8
#  148  CustomerDepartmentHumanResources                         uint8
#  149  CustomerDepartmentInformationTechnology                  uint8
#  150  CustomerDepartmentOperations                             uint8
#  151  CustomerDepartmentResearchandDevelopment                 uint8
#  152  EmployerBusinessActivityAccountingBankingandfinance      uint8
#  153  EmployerBusinessActivityAutomotive                       uint8
#  154  EmployerBusinessActivityBusinessConsultingandManagement  uint8
#  155  EmployerBusinessActivityCharityandVoluntaryWork          uint8
#  156  EmployerBusinessActivityChildcare                        uint8
#  157  EmployerBusinessActivityCleaningActivities               uint8
#  158  EmployerBusinessActivityConstruction                     uint8
#  159  EmployerBusinessActivityCreativeArtsandDesign            uint8
#  160  EmployerBusinessActivityElectricalInstallations          uint8
#  161  EmployerBusinessActivityEnergyandUtilities               uint8
#  162  EmployerBusinessActivityEngineeringandManufacturing      uint8
#  163  EmployerBusinessActivityEnvironmentandAgriculture        uint8
#  164  EmployerBusinessActivityFactory                          uint8
#  165  EmployerBusinessActivityHairBeauty                       uint8
#  166  EmployerBusinessActivityHealthcare                       uint8
#  167  EmployerBusinessActivityHospitalityandCatering           uint8
#  168  EmployerBusinessActivityITComputing                      uint8
#  169  EmployerBusinessActivityInformationTechnology            uint8
#  170  EmployerBusinessActivityLaw                              uint8
#  171  EmployerBusinessActivityMarketingAdvertisingandPR        uint8
#  172  EmployerBusinessActivityMediaandInternet                 uint8
#  173  EmployerBusinessActivityPropertyandRealEstate            uint8
#  174  EmployerBusinessActivityPublicServicesandAdmin           uint8
#  175  EmployerBusinessActivityRecruitmentandHR                 uint8
#  176  EmployerBusinessActivityRetailandWholesale               uint8
#  177  EmployerBusinessActivitySales                            uint8
#  178  EmployerBusinessActivityScienceandPharmaceuticals        uint8
#  179  EmployerBusinessActivitySocialCare                       uint8
#  180  EmployerBusinessActivitySportsandLeisure                 uint8
#  181  EmployerBusinessActivityTeachingandEducation             uint8
#  182  EmployerBusinessActivityTransportlogisticsandStorage     uint8
#  183  EmployerBusinessActivityTravelandTourism                 uint8
#  184  LoanApplicationMethodInPerson                            uint8
#  185  LoanApplicationMethodOnline                              uint8
#  186  LoanTypeBronze                                           uint8
#  187  LoanTypeGold                                             uint8
#  188  LoanTypePlatinum                                         uint8
#  189  LoanTypeSilver                                           uint8
#  190  LoanType                                                 object
# dtypes: datetime64[ns](1), int64(1), object(2), uint8(187)
# memory usage: 898.7+ KB

# %% [markdown]
# The next code block split the loans data into completed (with status "Repaid" or "Defaulted") and live (which do not have a status yet as they have not yet completed) and then further splits the completed loans into a training and testing set.

# %%
completed_filter = df_loans["LoanStatus"].isin(["Repaid", "Defaulted"])
df_completed = df_loans[completed_filter].copy(deep=True)
df_live = df_loans[~completed_filter].copy(deep=True)

X = df_completed.drop(["LoanStatus", "LoanType", "LoanExpectedEndDate"], axis=1)
y = df_completed["LoanStatus"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    
print(X_train.shape, X_test.shape)
# Out:
# (2214, 188) (739, 188)

# %% [markdown]
# ### Building a Machine Learning Model
# The next stage is to train a model based on the training data and to use it to make predictions for the test data which can be evaluated for accuracy and to make predictions for the live data which cannot be evaluated using traditional metrics as the outcome is not yet known.

# %%
# Fit a LightGBM classifier using the training data
model = LGBMClassifier(random_state=42)
model.fit(X_train, y_train)

# Make a set of predictions for the test data and show the accuracy
y_test_pred = model.predict(X_test)
print(f"Accuracy score of the model for the testing data: {accuracy_score(y_test, y_test_pred):.1%}")
# Out:
# Accuracy score of the model for the testing data: 69.1%

# %% [markdown]
# ### Evaluating Overall Performance
# We cannot know the accuracy of the model against the live / production data as those loans will not have a classification label until they complete, but there are other ways that performance can at least be hinted at.
#
# For example, lets take a look at the overall ratio of defaulted and repaid for all the loans that have already completed.

# %% [markdown]
# So 34.8% of loans default and 65.2% of loans repay.
#
# Now lets take a look at the overall ratio for the predictions on the test data.

# %%
df_completed["LoanStatus"].value_counts(normalize=True).sort_index().plot.bar()
plt.show()

# %% [markdown]
# Now lets take a look at the overall ratio for predictions against the loans that are currently live and active.

# %%
y_live_pred = model.predict(df_live.drop(["LoanStatus", "LoanType", "LoanExpectedEndDate"], axis=1))
pd.Series(y_live_pred).value_counts(normalize=True).sort_index().plot.bar()
plt.show()

# %% [markdown]
# The model is predicting a 76.1% overall ratio of defaults which is very different from 34.8% for all historic loans and 23.8% for the test data!
#
# Sure enough when we check with our domain users (who do not exist remember as this is fictitious data!) they report back that from their observation and experience they expect the defaults on future loans to broadly outturn in a similar way to historic loans.
#
# At this point we appear to have a big problem. Our machine learning model is predicting overall ratios that the domain users do not recognise and cannot accept.
#
# So what is happening? Is there a massive flaw in our model causing it to be overly pessimistic? Are the domain users wrong and the loan paerformance is about to drop off a cliff? Or could it be something else entirely?
#
# This is the problem I was facing in my real world project (albeit on completely different data with actual real-world domain experts!).
#
# The rest of this article describes how I used data stratification in the solution I came up with to build a model that could be used with confidence by the  users to deliver impact and outcomes in their business domain.

# %% [markdown]
# ### Explaining the Model
# The first step in finding a solution was to build a much better understnading of how the model was making its predictions and I have found the SHAP library to be a great way to do this.
#
# If you would like to know more about the SHAP library, here is a link to the documentation - https://shap.readthedocs.io/en/latest/index.html.
#
# When building machine learning models data scientists face a dilemma. We can build models using advanced techniques including stacking and voting or we can try to scale data or artificially engineer features all of which may drive small improvements in performance.
#
# However, every time we take a towards complexity and data obscurity we take a step away from model explainability and in the real world we need to make a conscious desicion about which of these is more improtant in the business context of the project we are working on.
#
# In the real-world project and in the example presented here I have made the assumption that being able to understand the predictions is more important. This has shaped the way I built the model inb the code above and it enables the use of the SHAP model to visualise how the predictions are being made.

# %%
explainer = Explainer(model, X_train)
shap_values = explainer(X_test, check_additivity=False)

plots.bar(shap_values, max_display=12)

# %% [markdown]
# The code above uses the machine learning model coupled with the training data to explain what is happening within the test data. I have seen many examples online that miss the point about explaining the test data but this is the correct way to visualise what is going on.
#
# What this means is that ``LoanTypePlatinum`` is the feature that adds the biggest weight to the model prediction, followed by ``LoanTypeBronze`` in 2nd place and ``EmployerNumberOfEmployees`` in 3rd place.
#
# We can also use shap to take a look at how a prediction was made for an individual customer ...

# %%
print(y_test_pred[0])
plots.waterfall(shap_values[0], max_display=12)
# Out:
# Repaid

# %% [markdown]
# Here we are looking at the explanation for the 1st row of test data (with index 0). We can see that the model prediction was for "Defaulted" and that ``LoanTypePlatinum`` had the biggest impact on that prediction.

# %%
print(y_test_pred[3])
plots.waterfall(shap_values[3], max_display=12)
# Out:
# Defaulted

# %% [markdown]
# The next record (with index 1) had a prediction of "Repaid" and we can see that ``LoanTypeBronze`` is the most significant factor in this prediction.
#
# It is beginning to look like "Platinum" loans are more likely to lead to a prediction of "Default" and "Bronze" loans to a prediction of "Repaid".
#
# Armed with this knowledge we now need to go back to our (still fictitious!) domain experts to explore why "Platimum" loans look to be defaulting and what the reasons might be.

# %% [markdown]
# ### Eureka! Understanding the Problem!
# Our non-existent domain experts think they can spot the problem. It transpires that "Platinum" loans have only recently been introduced and that over a period of time all bronze, silver and gold loans are being phased out so there will only be "Platinum" loans moving forward.
#
# Furthermore the business is currently in the middle of the transition period. The domain experts suspect that most of the "Platinum" loans have not existed long enough to complete the repayment term and they are either defaulted or on-going.
#
# Let's take a quick look at the data to test this theory out.

# %%
df_loans[completed_filter]["LoanType"].value_counts(normalize=True).sort_index(key=lambda x: x.map({'Bronze': 0, 'Silver': 1, 'Gold': 2, 'Platinum': 3} )).plot.bar()
plt.show()

# %% [markdown]
# This tells us that the completed loans are 41% Bronze, 22% Silver, 14% Gold and 23% Platinum.
#
# Now lets have a look at the live loans ...

# %%
df_loans[~completed_filter]["LoanType"].value_counts(normalize=True).sort_index(key=lambda x: x.map({'Bronze': 0, 'Silver': 1, 'Gold': 2, 'Platinum': 3})).plot.bar()
plt.show()

# %% [markdown]
# They are 95% "Platinum", so this bears out what the domain experts are telling us. Now lets the second part of the theory - that the "Platinum" loans are too new to have finished (repaid) yet in significant numbers -

# %%
old_loans_filter = df_loans["LoanType"].isin(["Bronze", "Silver", "Gold"])

df_loans[old_loans_filter]["LoanStatus"].fillna("Live").value_counts(normalize=True).plot.bar()
plt.show()

# %%
df_loans[~old_loans_filter]["LoanStatus"].fillna("Live").value_counts(normalize=True).plot.bar()
plt.show()

# %% [markdown]
# This provides a good verification for the domain experts theory. Most of the "Platinum" loans are too new to have completed yet. A large proportion of those that have completed have done so because they have defaulted before the loan term is up and this is skewing our machine learning model to associate "Platinum" loans with defaulting even though this may not be true in future.

# %% [markdown]
# ### Eureka Mk II! Fixing the Problem
# In the real world problem I came up with this approach as a potential solution: I would stratify the training data to contain the same proportion of "Platinum" loans as the future data. In theory this should remove the platinum type as the most significant feature in the model predictions and use other features instead. Also this would provide training data that is a much better fit to what the future production data is going to look like.
#
# What we need now is a function that stratifies one ``DataFrame`` based on the proportions found in another.

# %%
def stratify(sample : pd.DataFrame, population : pd.DataFrame, stratify_cols : list, random_state : int = 42) -> Tuple[pd.DataFrame, pd.Series]:
    weights = (population[stratify_cols].value_counts(normalize=True) * sample.shape[0]).astype(int)

    df_return = sample.groupby(stratify_cols).apply(lambda group: group.sample(n=weights[group.name] if group.name in weights else 0, replace=True, random_state=random_state))
    df_return.index = df_return.index.droplevel(level=stratify_cols)
    
    return df_return, weights

# %%
#df_completed = df_loans_encoded[completed_filter].copy(deep=True)

# %%
#df_completed["LoanType"] = df_loans[completed_filter]["LoanType"]
#df_live["LoanType"] = df_loans[~completed_filter]["LoanType"]

end_date_filter = df_completed["LoanExpectedEndDate"] <= pd.to_datetime("30/04/2022", format=r"%d/%m/%Y")

df_completed_stratified, weights = stratify(sample=df_completed[end_date_filter], population=df_live, stratify_cols=["LoanType"], random_state=42)

df_completed_stratified["LoanType"].value_counts(normalize=True)#.sort_index(key=lambda x: x.map({'Bronze': 0, 'Silver': 1, 'Gold': 2, 'Platinum': 3}))
# Out:
# Platinum    0.948868
# Silver      0.025201
# Bronze      0.014244
# Gold        0.011687
# Name: LoanType, dtype: float64

# %%
weights
# Out:
# LoanType
# Platinum    2598
# Silver        69
# Bronze        39
# Gold          32
# dtype: int32

# %%
X = df_completed_stratified.drop(["LoanStatus", "LoanType", "LoanExpectedEndDate"], axis=1)
y = df_completed_stratified["LoanStatus"]

#X = df_completed[end_date_filter].drop(["LoanStatus", "LoanType", "LoanExpectedEndDate"], axis=1)
#y = df_completed[end_date_filter]["LoanStatus"]


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    
print(X_train.shape, X_test.shape)
# Out:
# (2053, 188) (685, 188)

# %% [markdown]
# So now we have a set of training data that stratifies the ``LoanType`` in such a way that it is representative of the future, production data. Lets take a look and see if it has worked ...

# %%
model = LGBMClassifier(random_state=42)
model.fit(X_train, y_train)

# Make a set of predictions for the test data and show the accuracy
y_test__stratified_pred = model.predict(X_test)
print(f"Accuracy score of the model for the testing data: {accuracy_score(y_test, y_test__stratified_pred):.1%}")
# Out:
# Accuracy score of the model for the testing data: 82.8%

# %%
explainer = Explainer(model, X_train)
shap_values = explainer(X_test, check_additivity=False)

plots.bar(shap_values, max_display=12)

# %%
pd.Series(y_test__stratified_pred).value_counts(normalize=True).sort_index().plot.bar()
plt.show()
