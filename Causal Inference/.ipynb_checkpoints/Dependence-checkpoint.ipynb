# %% [markdown]
# # Demystifying Dependence and Why it is Important in Causal Inference and Causal Validation
#
# ## A step-by-step guide in understanding the concept of dependence and how to apply it to validate directed acyclic graphs in causal validation

# %% [markdown]
# ![ana-municio-PbzntH58GLQ-unsplash.jpg](attachment:ana-municio-PbzntH58GLQ-unsplash.jpg)
